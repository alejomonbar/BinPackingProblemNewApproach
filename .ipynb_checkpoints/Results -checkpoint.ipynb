# %%
from functions import BinPacking, BinPackingNewApproach, new_eq_optimal,  get_figure, interpret, eval_constrains
from functions import mapping_cost, cost_func, qaoa_circuit, check_best_sol
from qiskit.algorithms import QAOA, NumPyMinimumEigensolver
from qiskit_optimization.algorithms import CplexOptimizer, MinimumEigenOptimizer
from qiskit.algorithms.optimizers import COBYLA
import numpy as np
from qiskit_optimization.problems.constraint import ConstraintSense
import matplotlib.pyplot as plt
from scipy.optimize import minimize

from qiskit import Aer
backend = Aer.get_backend("qasm_simulator")

# %%
#np.random.seed(1)
num_items = 3 # number of items
num_bins = num_items # maximum number of bins
max_weight = 15 # max weight of a bin
cases = 100
solutions_new = {}
optimal_new = []
ratio_new = []; new =[]
result_classical = []; result_qaoa_new = []
check_const = []
weights=[]
qaoa = MinimumEigenOptimizer(QAOA(optimizer=COBYLA(maxiter=100), reps=4, quantum_instance=backend))
for i in range(cases): # Testing 5 different randomly selected configurations of the problem
    print(f"----------- Case {i+1} -------------")
    weights.append(np.random.randint(1, max_weight, num_items)) # Randomly picking the item weight
    qubo_new = BinPackingNewApproach(num_items, num_bins, weights[-1], max_weight, alpha=1, simplification=True)
    qubo_classical, qp = BinPacking(num_items, num_bins, weights[-1], max_weight, simplification=True)
    result_classical.append(CplexOptimizer().solve(qubo_classical))
    optimal_new.append(new_eq_optimal(qubo_new, qubo_classical))
    result_qaoa_new.append(CplexOptimizer().solve(qubo_new))
    solutions_new = result_qaoa_new[-1].fval
    new.append(solutions_new)
    check_const.append(eval_constrains(qp, result_qaoa_new[-1].x, max_weight))
    print(check_const[-1])
# Out:
# ----------- Case 1 -------------
# True
# ----------- Case 2 -------------
# True
# ----------- Case 3 -------------
# True
# ----------- Case 4 -------------
# True
# ----------- Case 5 -------------
# True
# ----------- Case 6 -------------
# True
# ----------- Case 7 -------------
# True
# ----------- Case 8 -------------
# True
# ----------- Case 9 -------------
# True
# ----------- Case 10 -------------
# True
# ----------- Case 11 -------------
# True
# ----------- Case 12 -------------
# True
# ----------- Case 13 -------------
# True
# ----------- Case 14 -------------
# True
# ----------- Case 15 -------------
# True
# ----------- Case 16 -------------
# True
# ----------- Case 17 -------------
# True
# ----------- Case 18 -------------
# True
# ----------- Case 19 -------------
# True
# ----------- Case 20 -------------
# True
# ----------- Case 21 -------------
# True
# ----------- Case 22 -------------
# True
# ----------- Case 23 -------------
# True
# ----------- Case 24 -------------
# True
# ----------- Case 25 -------------
# True
# ----------- Case 26 -------------
# True
# ----------- Case 27 -------------
# True
# ----------- Case 28 -------------
# True
# ----------- Case 29 -------------
# True
# ----------- Case 30 -------------
# True
# ----------- Case 31 -------------
# True
# ----------- Case 32 -------------
# True
# ----------- Case 33 -------------
# True
# ----------- Case 34 -------------
# True
# ----------- Case 35 -------------
# True
# ----------- Case 36 -------------
# True
# ----------- Case 37 -------------
# True
# ----------- Case 38 -------------
# True
# ----------- Case 39 -------------
# True
# ----------- Case 40 -------------
# True
# ----------- Case 41 -------------
# True
# ----------- Case 42 -------------
# True
# ----------- Case 43 -------------
# True
# ----------- Case 44 -------------
# True
# ----------- Case 45 -------------
# True
# ----------- Case 46 -------------
# True
# ----------- Case 47 -------------
# True
# ----------- Case 48 -------------
# True
# ----------- Case 49 -------------
# True
# ----------- Case 50 -------------
# True
# ----------- Case 51 -------------
# True
# ----------- Case 52 -------------
# True
# ----------- Case 53 -------------
# True
# ----------- Case 54 -------------
# True
# ----------- Case 55 -------------
# True
# ----------- Case 56 -------------
# True
# ----------- Case 57 -------------
# True
# ----------- Case 58 -------------
# True
# ----------- Case 59 -------------
# True
# ----------- Case 60 -------------
# True
# ----------- Case 61 -------------
# True
# ----------- Case 62 -------------
# True
# ----------- Case 63 -------------
# True
# ----------- Case 64 -------------
# True
# ----------- Case 65 -------------
# True
# ----------- Case 66 -------------
# True
# ----------- Case 67 -------------
# True
# ----------- Case 68 -------------
# True
# ----------- Case 69 -------------
# True
# ----------- Case 70 -------------
# True
# ----------- Case 71 -------------
# True
# ----------- Case 72 -------------
# True
# ----------- Case 73 -------------
# True
# ----------- Case 74 -------------
# True
# ----------- Case 75 -------------
# True
# ----------- Case 76 -------------
# True
# ----------- Case 77 -------------
# True
# ----------- Case 78 -------------
# True
# ----------- Case 79 -------------
# True
# ----------- Case 80 -------------
# True
# ----------- Case 81 -------------
# True
# ----------- Case 82 -------------
# True
# ----------- Case 83 -------------
# True
# ----------- Case 84 -------------
# True
# ----------- Case 85 -------------
# True
# ----------- Case 86 -------------
# True
# ----------- Case 87 -------------
# True
# ----------- Case 88 -------------
# True
# ----------- Case 89 -------------
# True
# ----------- Case 90 -------------
# True
# ----------- Case 91 -------------
# True
# ----------- Case 92 -------------
# True
# ----------- Case 93 -------------
# True
# ----------- Case 94 -------------
# True
# ----------- Case 95 -------------
# True
# ----------- Case 96 -------------
# True
# ----------- Case 97 -------------
# True
# ----------- Case 98 -------------
# True
# ----------- Case 99 -------------
# True
# ----------- Case 100 -------------
# True

# %%
np.sum(check_const)/cases
# Out:
# 1.0

# %%
for i in range(len(result_classical)):
    fig = get_figure(interpret(result_classical[i].x, weights[i], max_weight, num_items, num_bins, simplify=True), weights[i], max_weight, title=f"-------Case {i+1}-----")
    fig = get_figure(interpret(result_qaoa_new[i].x, weights[i], max_weight, num_items, num_bins, simplify=True), weights[i], max_weight, title="New")
# Out:
# /Users/alejomonbar/Documents/GitHub/BinPackingProblemNewApproach/functions.py:157: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots()

# %%
n = 50
alpha = np.linspace(0, 2*np.pi, n)
beta = np.linspace(0, np.pi, n)
map_cost_10 = mapping_cost(alpha, beta, qubo_new, n = 10)
map_cost_20 = mapping_cost(alpha, beta, qubo_new, n = 20)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,10))
ax[0].imshow(np.log(map_cost_10))
ax[1].imshow(np.log(map_cost_20))
for i in range(2):
#     ax[i].set_xticks([0,9,19], ["0", r"$\pi/2$", r"$\pi$"])
#     ax[i].set_yticks([0,9,19], ["0", r"$\pi$", r"2$\pi$"])
    ax[i].set_xlabel(r"$\beta$", fontsize=22)
    ax[i].set_ylabel(r"$\alpha$", fontsize=22)

# %%
x0 = np.random.rand(2)
circuit = qaoa_circuit(qubo_new)
objective = qubo_new.objective
num_evals = -1
fmin = minimize(cost_func, x0, args = (circuit, objective, num_evals), method="COBYLA")

# %%
check_best_sol(fmin.x, circuit, qp, max_weight)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-2e210a87a1f0> in <module>
# ----> 1 check_best_sol(fmin.x, circuit, qp, max_weight)
#
# ~/Documents/GitHub/BinPackingProblemNewApproach/functions.py in check_best_sol(parameters, circuit, qp, max_weight, n, backend)
#     274         sample_list = [int(_) for _ in sample]
#     275         cost = qp.objective.evaluate(sample_list)
# --> 276         if eval_constrains(qp, sample_list, max_weight) and (cost < cost_min):
#     277             best_solution = sample_list
#     278     if best_solution == None:
#
# ~/Documents/GitHub/BinPackingProblemNewApproach/functions.py in eval_constrains(qp, result, max_weight)
#     319     for const in constraints:
#     320         if const.sense in [ConstraintSense.GE, ConstraintSense.LE]:
# --> 321             eval_const.append(const.evaluate(result.x[:varN]) - max_weight)
#     322     return not any(np.array(eval_const) > 0)
#     323
#
# AttributeError: 'list' object has no attribute 'x'

# %%
print(f" minimum my cost_fun {fmin.fun}, minimum with cplex {result_qaoa_new[-1].fval}")
# Out:
#  minimum my cost_fun 14754.136852394917, minimum with cplex 422.0

# %%
result_qaoa_new[-1].x
# Out:
# array([0., 0., 1., 0., 0., 1., 0.])
